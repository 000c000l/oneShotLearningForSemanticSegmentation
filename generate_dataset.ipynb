# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import pickle

OMNIGLOT_DATA = os.path.join(os.getcwd(), 'omniglot/')
DATASET_DIR = os.path.join(os.getcwd(), 'cluttered_omniglot/')

import time
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 12.0)

import dataset_utils

from joblib import Parallel, delayed

# %% [markdown]
# ### Create config file

# %%
config = dataset_utils.DatasetGeneratorConfig()

# %% [markdown]
# ### Load Omniglot Dataset

# %%
def reorder_chars(chars):
    reordered_chars=[]
    for alph in range(len(chars)):
        for char in range(len(chars[alph])):
            reordered_chars.append(chars[alph][char])
    
    return reordered_chars

#Load chars from pickle file
path = OMNIGLOT_DATA

#Train split
with open(path + 'chars_train.pickle', 'rb') as fp:
    chars_train = pickle.load(fp)
    chars_train = reorder_chars(chars_train)
    
#Evaluation split
with open(path + 'chars_eval.pickle', 'rb') as fp:
    chars_eval = pickle.load(fp)
    chars_eval = reorder_chars(chars_eval)
    
#Test split
with open(path + 'chars_test.pickle', 'rb') as fp:
    chars_test = pickle.load(fp)
    chars_test = reorder_chars(chars_test)

# %% [markdown]
# ### Dataset Generation Script

# %%
checksums = {4: [b'\x8c\x99\x9e\\J\x9a\x811g.eB\xa0\xb3\xf2f', 
              b';\xf8\x05\xb2vk#!\xf9\xad\xb9\x88\xd1\n\x0f\xba', 
              b'\xc6\x84\xf4\x99\x18<cx\x82\xeb\xed*\xbb\xca\x12\x8b', 
              b'\xd3\x8c\x88\rM\xdfSpK\xa7\xf2f\n?\x0e\xad'], 
             8: [b'\x0cY\x0f\xf4#\x872:2\xe1\x12R\xcf\x95rh', 
              b'\x92\x7f\xa3>@\x0cl\xaa\x96\xd7\xad\xbaOj\xdd\xac', 
              b'\xb9m\xc0\xbdN8\xf2\x0fkk\x8c&N\x88\xe2\xb0', 
              b'M\xf1\x8d\r\xe6\xf5\xba\tR\xe3\xcc\xd2\x91\xf2\x96\x81'], 
             16: [b'2}\x08\xf3\xe1\xb1\xb1\xb5\xed\x89\x05\xf1c\xedy^', 
              b'\x8bs>\x95\xa8n9Nw\xf0E\x83\xf8~+\xf2', 
              b'\xde8\xa6\x04\xdfq<\xf0\x05&a\x00EB\xc9B', 
              b'\xbf\x87uy\xec\x90\xbf \x9a\x96x\x9e\xd9w\xd3\x94'], 
             32: [b'\x813\x89v\xc8\xbd\xc16\x8dN\xc5Z\x9eS=y', 
              b'o\xd4\xe0a\x8a\x80\x0f\xba2_\x06\xffE\xed\xf9n', 
              b':\x05\xe2\x03\xfb\x85\x84\x18\xc5\x18\x81d\xd9V\xb9[', 
              b'\xcc\x96\xe1D\x90\xba\xed\xa3\xff\x1c\xd7\xd7\xdf\xe4\xd0A'], 
             64: [b'\x11\x19HZ\x05-\xf3A\xe8\xe6\x0f\x9f\x14\n\xcb\x17', 
              b'VP\x0c\xcf\xa0\xef\x07_\x85[\xa7\x0cL*|\xa2', 
              b'(\x0f\xba,\x0c\x98+\x85\xa9n\xd0a\x1b\xe0p\x03', 
              b'W\xf4\xc7\xed\x19f\xc50f\xb3\xb3\xc8\x80\xf0\xda\x90'], 
             128: [b'\x8a\x11O\x805\xb6\xcf\xf0L\xaf\xad\x93\xbf&/\xb2', 
              b'\xc8\xd16\xfa\xb2\x16h\xd8\xa3h\xf5\x8e\xa7\x00\x90v', 
              b'\x05\xd2\xd94T\xe1\xbb\xb63\x90\x9eX\xd8\t\xfc\xb9', 
              b'el\x85\xda\xfcw\xce\xe0\xf5\x9c\xb7 v\xc6J='], 
             256: [b's\xffZO\xc1j\x87\x7f\xbf\x1fj\xf2]\xc9\x9f\x14', 
              b'D\xbe\x0eZ%\xb2\x16Z\xea\x18S\x1d!6\xd0w', 
              b'\xfbZ\xe4$\x06\xd88J\x99\xfa\x0b*\x92\xdd\xa3\xa8', 
              b'z\xee@d\x0f}\xe8\xd3\xf3\xad\xf7\xe8\xc9]\xfbb']}

# %%
# Generate indicidual datasets for each clutter level
nname =  [4, 8, 16, 32, 64, 128, 256]
nchars = [3, 7, 15, 31, 63, 127, 255]

for i in range(len(nname)):
    # Set and print saving directory
    dset_dir = DATASET_DIR + '{}_characters/'.format(nname[i])
    print('')
    print(dset_dir)

    # Set number of images per parallel job
    config.JOBLENGTH = 2000
    # Set number of distractors
    config.DISTRACTORS = nchars[i]
    
    ### Generate training set ###
    
    # Set dataset split
    config.DRAWER_SPLIT = 'train'
    config.set_drawer_split()
    # Define number of train images
    dataset_size = 20000 #2000000 
    # Choose training alphabets
    chars = chars_train
    # Set path
    path = dset_dir + 'train/'
    # Set a fixed seed
    seed_train = 2209944264

    # Generate dataset
    print('Generating dataset train/')
    dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=seed_train, save=True)
    print('')


    ### Generate evaluation and test sets ###

    # Set dataset split
    config.DRAWER_SPLIT = 'val'
    config.set_drawer_split()
    # Define number of val/test images
    dataset_size = 100 #10000

    #Generate evaluation set on train characters
    seed_val_train = 4020197800
    chars = chars_train
    path = dset_dir + 'val-train/'
    print('Generating dataset val-train/')
    dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=seed_val_train, save=True, checksum=checksums[nname[i]][0])
    print('')
    
    #Generate test set on train characters
    seed_test_train = 1665765955
    chars = chars_train
    path = dset_dir + 'test-train/'
    print('Generating dataset test-train/')
    dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=seed_test_train, save=True, checksum=checksums[nname[i]][1])
    print('')

    #Generate evaluation set on one-shot characters
    seed_val_one_shot = 3755213170
    chars = chars_eval
    path = dset_dir + 'val-one-shot/'
    print('Generating dataset val-one-shot/')
    dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=seed_val_one_shot, save=True, checksum=checksums[nname[i]][2])
    print('')

    #Generate test set on one-shot characters
    seed_test_one_shot = 2301871561
    chars = chars_test
    path = dset_dir + 'test-one-shot/'
    print('Generating dataset test-one-shot/')
    dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=seed_test_one_shot, save=True, checksum=checksums[nname[i]][3])
    print('')

print('')
print('All Done')
# Out:
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/4_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:   10.5s remaining:   42.1s
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   11.2s remaining:   26.2s
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:   13.3s remaining:   19.9s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   15.7s remaining:   15.7s
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:   17.2s remaining:   11.5s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   19.1s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:   20.7s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   22.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   22.2s finished
# Duration: 23.500116109848022
# Hash: b'\x08xi\xc1\xce\x8c\x86BW\xa5\xafMe\x8c\xc6\x12'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005303621292114258
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.00508427619934082
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004873752593994141
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0052700042724609375
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/8_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:   16.5s remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   18.2s remaining:   42.5s
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:   21.5s remaining:   32.3s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   22.4s remaining:   22.4s
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:   23.5s remaining:   15.6s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   25.4s remaining:   10.9s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:   26.9s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   29.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   29.7s finished
# Duration: 30.865535736083984
# Hash: b'\xa1\xcf(\x9c\x03\xfa\xc78\x1fRsX\xda\tFC'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0052640438079833984
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005357503890991211
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005115032196044922
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005746126174926758
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/16_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:   31.3s remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   34.8s remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:   35.0s remaining:   52.5s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   37.6s remaining:   37.6s
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:   39.0s remaining:   26.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   41.8s remaining:   17.9s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:   42.3s remaining:   10.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   52.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   52.2s finished
# Duration: 53.71345806121826
# Hash: b'A\xb5p\xc7\x1f>\xc6\xb4D\xe7\\\x05\xb17t-'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005233287811279297
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.00473785400390625
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0049591064453125
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0052509307861328125
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/32_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:   54.1s remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   54.5s remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:  1.0min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.0min remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  1.1min remaining:   42.2s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.1min remaining:   27.2s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:  1.1min remaining:   16.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.5min finished
# Duration: 91.09002900123596
# Hash: b'\x04x"\xd7\xd3\x0e\xff\xde\x90\xdf\xdd/z}Sb'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.006445884704589844
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005732059478759766
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005265474319458008
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005495786666870117
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/64_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:  1.7min remaining:  7.0min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  1.8min remaining:  4.2min
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:  1.9min remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.9min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  1.9min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  1.9min remaining:   49.3s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:  2.0min remaining:   29.4s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.8min finished
# Duration: 169.18355083465576
# Hash: b'\x15\xe9\x18\xf6\xea3\xfc\xfd`<\xae|z}\x8d\x13'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004585742950439453
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0044782161712646484
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.005867481231689453
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004789590835571289
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/128_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:  3.7min remaining: 14.9min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  3.8min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:  3.8min remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  3.8min remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  3.9min remaining:  2.6min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  3.9min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:  3.9min remaining:   58.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  5.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  5.9min finished
# Duration: 354.35810375213623
# Hash: b'\xe7\xc8\x9e\x8f\xf9K\xd3\x9c\xc5H-e\xd3\x9c\x1cR'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.00698399543762207
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.007475614547729492
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.00603938102722168
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.00537562370300293
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# /home/siddharth/Interests/tarahAI/cluttered-omniglot/cluttered_omniglot/256_characters/
# Generating dataset train/
# Executing 10 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:  6.6min remaining: 26.6min
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  6.6min remaining: 15.5min
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:  6.7min remaining: 10.0min
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  6.7min remaining:  6.7min
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  6.7min remaining:  4.5min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  6.7min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:  6.9min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 10.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 10.5min finished
# Duration: 632.7040665149689
# Hash: b'0\x83\xd1\xca\x8f\x974\xae\xfaP\xc5\xce\x83\x06]\xb4'
#
# Generating dataset val-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.0049707889556884766
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-train/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004869937896728516
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset val-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004554033279418945
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
# Generating dataset test-one-shot/
# Executing 0 tasks
# Seed fixed
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Duration: 0.004734516143798828
# Hash: b'\x0cV\xb0\x88\xea;\x94\x9f\x89\xd0\xa6\xaa\xed\xefTJ'
# Incorrect hash value!
#
#
# All Done

# %% [markdown]
# ### Dataset Visualization Script

# %%
#Show some randomly generated example images

# Define number of images
dataset_size = 5

# Choose training alphabets
chars = chars_train
# Set number of images per parallel job
config.JOBLENGTH = 1
# Set number of distractors
config.DISTRACTORS = 7
# Set dataset split
config.DRAWER_SPLIT = 'train'
config.set_drawer_split()

# set path if images should be saved
dset_dir = DATASET_DIR + '{}_characters/'.format(config.DISTRACTORS + 1)
path = DATASET_DIR + 'visualize/'

# Run visualization
dataset_utils.generate_dataset(path, dataset_size, chars, config, seed=None, save=False, show=True)
# Out:
# Executing 5 tasks
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.6s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:    3.8s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.1s finished
# Duration: 9.797956943511963
# Hash: b'\xe7N\xcf\x03/\x00i\xbb\xde\xaa\xbb\x14^\xfd\x94J'
